# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('python_task_dataset.csv')
p = data['device_type'].value_counts()
print(p)
# Out:
# device_type
# android    228595
# ios         36808
# Name: count, dtype: int64

# %%
s = data['gender'].value_counts()
print(s)
# Out:
# gender
# 1    226616
# 0     28347
# 2     10440
# Name: count, dtype: int64

# %%
a = data['age'].value_counts()
plt.bar(a.index, a.values)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
e = data['ev_type'].value_counts()
print(e)
# Out:
# ev_type
# 0    261295
# 1      4108
# Name: count, dtype: int64
