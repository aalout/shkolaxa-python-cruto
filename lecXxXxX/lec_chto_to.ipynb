# %%
import pandas as pd
# %pip install scikit_learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting scikit_learn
# ...
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.1/9.2 MB 409.6 kB/s eta 0:00:23
#      ---------------------------------------- 0.1/9.2 MB 409.6 kB/s eta 0:00:23
#      ---------------------------------------- 0.1/9.2 MB 383.3 kB/s eta 0:00:24
#      ---------------------------------------- 0.1/9.2 MB 383.3 kB/s eta 0:00:24
#      ---------------------------------------- 0.1/9.2 MB 276.8 kB/s eta 0:00:33
#      ---------------------------------------- 0.1/9.2 MB 276.8 kB/s eta 0:00:33
# ...

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
miss_value = df.isnull()
miss_value_c = miss_value.sum()
print(miss_value_c)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_stats = df.describe()
print(df_stats)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df_1 = pd.read_csv('train.csv', usecols = ['PassengerId',	'Survived',	'Pclass', 'Age',	'SibSp',	'Parch', 'Fare'])
df_cr = abs(df_1.corr())
print(df_cr)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.005007  0.035144  0.036847  0.057527  0.001652
# Survived        0.005007  1.000000  0.338481  0.077221  0.035322  0.081629
# Pclass          0.035144  0.338481  1.000000  0.369226  0.083081  0.018443
# Age             0.036847  0.077221  0.369226  1.000000  0.308247  0.189119
# SibSp           0.057527  0.035322  0.083081  0.308247  1.000000  0.414838
# Parch           0.001652  0.081629  0.018443  0.189119  0.414838  1.000000
# Fare            0.012658  0.257307  0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass       0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
encoder = OneHotEncoder()
encoded_values = encoder.fit_transform(df.reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\pypy\lecXxXxX\lec_chto_to.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/pypy/lecXxXxX/lec_chto_to.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> encoder = OneHotEncoder()
#       <a href='vscode-notebook-cell:/d%3A/pypy/lecXxXxX/lec_chto_to.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> encoded_values = encoder.fit_transform(df.reshape(-1, 1))
#
# NameError: name 'OneHotEncoder' is not defined
